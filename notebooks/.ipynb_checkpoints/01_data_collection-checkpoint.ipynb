# %% [markdown]
# ## Data Collection

# %%
import os
import pandas as pd
import requests

# %%
from bs4 import BeautifulSoup #for scraping

# %% [markdown]
# ### Data Sources
#
# 1. Economic News
#    [ a.  Reuters,
#    b. Economic times,
#    c. other ]
# 2. Economic Indicators
#  [a. World bank
#  b. International Monetary Fund IMF]

# %%
economic = "../data/raw/"
os.makedirs(economic, exist_ok = True)

# %%
os.makedirs(os.path.join(economic_raw, "news"), exist_ok = True)

# %%
world_bank_url = ""

try:
    indicators_df = pd.read_csv(world_bank_url)
    indicators_df.to_csv( 
     os.path.join(Raw_data_dir, "economic_indicator_raw.csv"),
     index = False
    )
    print("Econmic indicators colled succesfully.")
except Exception as e:
    print("Error collecting econmic indicators:",e)

# %%
print("Files in raw data directory:")
print(os.listdir(Raw_data_dir))
